# %%
import pandas as pd

# %%
FakeNews=pd.read_excel('/Users/hlind/Downloads/FakeNews.xlsx')

# %%
#add StoryType column with Fake
FakeNews['StoryType']='Fake'

# %%
FakeNews.columns
# Out:
# Index(['when', 'url', 'tracker', 'StoryType'], dtype='object')

# %%
#drop when column
FakeNews.drop(['when'], axis=1, inplace=True)

# %%
FakeNews.head()
# Out:
#                                                  url  \
# 0  http://wayback.archive.org/web/20161004072420i...
# 1  http://wayback.archive.org/web/20161004072420i...
# 2  http://wayback.archive.org/web/20161004072420i...
# 3  http://wayback.archive.org/web/20161004072420i...
# 4  http://wayback.archive.org/web/20161004072420i...
#
#                           tracker StoryType
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# 3              Google Syndication      Fake
# 4  DoubleClick Ad Exchange-Seller      Fake

# %%
#separate the url column
FakeNews2= FakeNews['url'].str.split('_', expand=True).rename(columns=lambda x: "URL"+str(x+1))

# %%
FakeNews2.head()
# Out:
#                                               URL1                     URL2
# 0  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 1  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 2  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 3  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 4  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/

# %%
FakeNews2a=pd.concat([FakeNews, FakeNews2], axis=1)

# %%
FakeNews2a.head()
# Out:
#                                                  url  \
# 0  http://wayback.archive.org/web/20161004072420i...
# 1  http://wayback.archive.org/web/20161004072420i...
# 2  http://wayback.archive.org/web/20161004072420i...
# 3  http://wayback.archive.org/web/20161004072420i...
# 4  http://wayback.archive.org/web/20161004072420i...
#
#                           tracker StoryType  \
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# 3              Google Syndication      Fake
# 4  DoubleClick Ad Exchange-Seller      Fake
#
#                                               URL1                     URL2
# 0  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 1  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 2  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# ...

# %%
FakeNews2a.drop(['url'], axis=1)
# Out:
#                              tracker StoryType  \
# 0                        DoubleClick      Fake
# 1                         RevContent      Fake
# 2                        DoubleClick      Fake
# 3                 Google Syndication      Fake
# 4     DoubleClick Ad Exchange-Seller      Fake
# ...                              ...       ...
# 3334                     DoubleClick      Fake
# 3335              Google Syndication      Fake
# 3336  DoubleClick Ad Exchange-Seller      Fake
# 3337                         AddThis      Fake
# 3338                  Google Adsense      Fake
#
#                                                    URL1  \
# 0       http://wayback.archive.org/web/20161004072420id
# 1       http://wayback.archive.org/web/20161004072420id
# 2       http://wayback.archive.org/web/20161004072420id
# 3       http://wayback.archive.org/web/20161004072420id
# 4       http://wayback.archive.org/web/20161004072420id
# ...

# %%
#put back url column
FakeNews2a['url']=FakeNews2a["URL1"] + "_" + FakeNews2a["URL2"].map(str)

# %%
FakeNews2a.head()
# Out:
#                                                  url  \
# 0  http://wayback.archive.org/web/20161004072420i...
# 1  http://wayback.archive.org/web/20161004072420i...
# 2  http://wayback.archive.org/web/20161004072420i...
# 3  http://wayback.archive.org/web/20161004072420i...
# 4  http://wayback.archive.org/web/20161004072420i...
#
#                           tracker StoryType  \
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# 3              Google Syndication      Fake
# 4  DoubleClick Ad Exchange-Seller      Fake
#
#                                               URL1                     URL2
# 0  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 1  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 2  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# ...

# %%
FakeNews2a.drop(['URL1', 'URL2'], axis=1)
# Out:
#                                                     url  \
# 0     http://wayback.archive.org/web/20161004072420i...
# 1     http://wayback.archive.org/web/20161004072420i...
# 2     http://wayback.archive.org/web/20161004072420i...
# 3     http://wayback.archive.org/web/20161004072420i...
# 4     http://wayback.archive.org/web/20161004072420i...
# ...                                                 ...
# 3334  https://www.ncscooper.com/transgender-dog-unsu...
# 3335  https://www.ncscooper.com/transgender-dog-unsu...
# 3336  https://www.ncscooper.com/transgender-dog-unsu...
# 3337  https://www.ncscooper.com/transgender-dog-unsu...
# 3338  https://www.ncscooper.com/transgender-dog-unsu...
#
#                              tracker StoryType
# 0                        DoubleClick      Fake
# 1                         RevContent      Fake
# 2                        DoubleClick      Fake
# 3                 Google Syndication      Fake
# 4     DoubleClick Ad Exchange-Seller      Fake
# ...

# %%
#keep only the first ten rows
FakeNews.head(10)
# Out:
#                                                  url  \
# 0  http://wayback.archive.org/web/20161004072420i...
# 1  http://wayback.archive.org/web/20161004072420i...
# 2  http://wayback.archive.org/web/20161004072420i...
# 3  http://wayback.archive.org/web/20161004072420i...
# 4  http://wayback.archive.org/web/20161004072420i...
# 5  http://wayback.archive.org/web/20161004072420i...
# 6  http://wayback.archive.org/web/20161004072420i...
# 7  http://wayback.archive.org/web/20161001155200i...
# 8  http://wayback.archive.org/web/20161001155200i...
# 9  http://wayback.archive.org/web/20161001155200i...
#
#                           tracker StoryType
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# 3              Google Syndication      Fake
# 4  DoubleClick Ad Exchange-Seller      Fake
# 5                           Kixer      Fake
# 6                  Google Adsense      Fake
# ...

# %%
FakeNews3=FakeNews2a[:10]

# %%
FakeNews3.head()
# Out:
#                                                  url  \
# 0  http://wayback.archive.org/web/20161004072420i...
# 1  http://wayback.archive.org/web/20161004072420i...
# 2  http://wayback.archive.org/web/20161004072420i...
# 3  http://wayback.archive.org/web/20161004072420i...
# 4  http://wayback.archive.org/web/20161004072420i...
#
#                           tracker StoryType  \
# 0                     DoubleClick      Fake
# 1                      RevContent      Fake
# 2                     DoubleClick      Fake
# 3              Google Syndication      Fake
# 4  DoubleClick Ad Exchange-Seller      Fake
#
#                                               URL1                     URL2
# 0  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 1  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# 2  http://wayback.archive.org/web/20161004072420id  /http://alertchild.com/
# ...
