# %%
# importing packages
import pandas as pd
import seaborn as sns
import numpy as np
from scipy import stats
from scipy.stats import boxcox

# %%
# importing data
parks=pd.read_csv('/Users/hlind/Downloads/Seattle_ParksnRec.csv')

# %%
# checking data
parks.head()
# Out:
#   Geographic Region  Year  # of trips Winter  # of participants Winter  \
# 0           Central  2005                 13                       154
# 1           Central  2006                 17                       229
# 2           Central  2007                 17                       222
# 3           Central  2008                 18                       300
# 4           Central  2009                 18                       276
#
#    # of trips Spring  # of participants Spring  # of trips Summer  \
# 0                 18                       290                 20
# 1                 16                       227                 19
# 2                 15                       244                 13
# 3                 19                       335                 20
# 4                 23                       302                 25
#
#    # of participants Summer  # of trips Fall  # of participants Fall  \
# ...

# %% [markdown]
# # trips Winter

# %%
sns.distplot(parks['# of trips Winter'])
# Out:
# /var/folders/xf/chkgnkz55mvbhswk6vjbb9680000gn/T/ipykernel_82396/484135875.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(parks['# of trips Winter'])
# <AxesSubplot: xlabel='# of trips Winter', ylabel='Density'>

# %%
# positively skewed - square rooting data
parks['# of trips WinterSQRT']=np.sqrt(parks['# of trips Winter'])

# %%
sns.distplot(parks['# of trips WinterSQRT'])
# Out:
# /var/folders/xf/chkgnkz55mvbhswk6vjbb9680000gn/T/ipykernel_82396/270897197.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(parks['# of trips WinterSQRT'])
# <AxesSubplot: xlabel='# of trips WinterSQRT', ylabel='Density'>

# %%
# trying log
parks['# of trips WinterLOG']=np.log(parks['# of trips Winter'])

# %%
sns.distplot(parks['# of trips WinterLOG'])
# Out:
# /var/folders/xf/chkgnkz55mvbhswk6vjbb9680000gn/T/ipykernel_82396/2681494489.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(parks['# of trips WinterLOG'])
# <AxesSubplot: xlabel='# of trips WinterLOG', ylabel='Density'>

# %%
# to keep squared root histogram

# %% [markdown]
# # participants Winter

# %%
sns.displot(parks['# of participants Winter'])

# %%
# positively skewed - square rooting data
parks['# of participants WinterSQRT']=np.sqrt(parks['# of participants Winter'])

# %%
sns.displot(parks['# of participants WinterSQRT'])

# %%
# attempting log
parks['# of participants WinterLOG']=np.log(parks['# of participants Winter'])

# %%
sns.displot(parks['# of participants WinterLOG'])

# %%
# to keep squared root histogram

# %% [markdown]
# # trips Spring

# %%
sns.displot(parks['# of trips Spring'])

# %%
# positively skewed - square rooting data
parks['# of trips SpringSQRT']=np.sqrt(parks['# of trips Spring'])

# %%
sns.displot(parks['# of trips SpringSQRT'])

# %%
# attempting log
parks['# of trips SpringLOG']=np.log(parks['# of trips Spring'])

# %%
sns.displot(parks['# of trips SpringLOG'])

# %%
# keeping squared root histogram

# %% [markdown]
# # participants Spring

# %%
sns.displot(parks['# of participants Spring'])

# %%
# positively skewed - square rooting data
parks['# of participants SpringSQRT']=np.sqrt(parks['# of participants Spring'])

# %%
sns.displot(parks['# of participants SpringSQRT'])

# %%
# attempting log
parks['# of participants SpringLOG']=np.log(parks['# of participants Spring'])

# %%
sns.displot(parks['# of participants SpringLOG'])

# %%
# keeping squared root histogram

# %% [markdown]
# # trips Summer

# %%
sns.distplot(parks['# of trips Summer'])
# Out:
# /var/folders/xf/chkgnkz55mvbhswk6vjbb9680000gn/T/ipykernel_82698/1592919324.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(parks['# of trips Summer'])
# <AxesSubplot: xlabel='# of trips Summer', ylabel='Density'>

# %%
# positively skewed - square rooting data
parks['# of trips SummerSQRT']=np.sqrt(parks['# of trips Summer'])

# %%
sns.distplot(parks['# of trips SummerSQRT'])
# Out:
# /var/folders/xf/chkgnkz55mvbhswk6vjbb9680000gn/T/ipykernel_82698/1709635728.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(parks['# of trips SummerSQRT'])
# <AxesSubplot: xlabel='# of trips SummerSQRT', ylabel='Density'>

# %%
# now normally distributed

# %% [markdown]
# # participants Summer

# %%
sns.distplot(parks['# of participants Summer'])
# Out:
# /var/folders/xf/chkgnkz55mvbhswk6vjbb9680000gn/T/ipykernel_82698/670676415.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(parks['# of participants Summer'])
# <AxesSubplot: xlabel='# of participants Summer', ylabel='Density'>

# %%
# positively skewed - square rooting data
parks['# of participants SummerSQRT']=np.sqrt(parks['# of participants Summer'])

# %%
sns.distplot(parks['# of participants SummerSQRT'])
# Out:
# /var/folders/xf/chkgnkz55mvbhswk6vjbb9680000gn/T/ipykernel_82698/1858674381.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(parks['# of participants SummerSQRT'])
# <AxesSubplot: xlabel='# of participants SummerSQRT', ylabel='Density'>

# %%
# attempting log
parks['# of participants SummerLOG']=np.log(parks['# of participants Summer'])

# %%
sns.distplot(parks['# of participants SummerLOG'])
# Out:
# /var/folders/xf/chkgnkz55mvbhswk6vjbb9680000gn/T/ipykernel_82698/1450049554.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(parks['# of participants SummerLOG'])
# <AxesSubplot: xlabel='# of participants SummerLOG', ylabel='Density'>

# %%
# keeping squared root histogram
