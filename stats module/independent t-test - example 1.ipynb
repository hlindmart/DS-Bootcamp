# %% [markdown]
# # to see if mpg differs between compacts and large cars

# %%
# import packages
import pandas as pd
from scipy import stats
from scipy.stats import ttest_ind

# %% [markdown]
# # test for normality between compacts and large cars

# %%
# import dataset
hybrid=pd.read_excel('/Users/hlind/Downloads/hybrid2013.xlsx')

# %%
# normality in compacts
hybrid.mpg[hybrid.carclass=='C'].hist()
# Out:
# <AxesSubplot: >

# %%
# normality in large cars
hybrid.mpg[hybrid.carclass=='L'].hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# # independent t-test between compacts and large cars

# %%
# running independent ttest
ttest_ind(hybrid.mpg[hybrid.carclass=='C'], hybrid.mpg[hybrid.carclass=='L'])
# Out:
# Ttest_indResult(statistic=2.598820461640718, pvalue=0.026545168887970094)

# %%
# checking mean for compacts
hybrid.mpg[hybrid.carclass=='C'].mean()
# Out:
# 40.75

# %%
# checking mean for large cars
hybrid.mpg[hybrid.carclass=='L'].mean()
# Out:
# 28.5
